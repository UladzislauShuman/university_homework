# %% [markdown]
# # Задача линейной интерполяции

# %% [markdown]
# стр 1.0
#
# ![задача-линейной-интерполяции.png](attachment:задача-линейной-интерполяции.png)

# %% [markdown]
# # Фундаментальный базис интерполяции

# %% [markdown]
# стр 1.1
#
# Основное
#
# ![Фундаментальный базис интерполяции-1.png](<attachment:Фундаментальный базис интерполяции-1.png>)
#
# Как я думаю, побочное
#
# ![Фундаментальный базис интерполяции-2.png](<attachment:Фундаментальный базис интерполяции-2.png>)
# ![Фундаментальный базис интерполяции-3.png](<attachment:Фундаментальный базис интерполяции-3.png>)

# %% [markdown]
# # Записать формулу интерполяционного многочлена в форме Ньютона

# %% [markdown]
# стр 2.1
#
# ![Записать формулу интерполяционного многочлена в форме Ньютона-1.png](<attachment:Записать формулу интерполяционного многочлена в форме Ньютона-1.png>)
#
# ![Записать формулу интерполяционного многочлена в форме Ньютона-2.png](<attachment:Записать формулу интерполяционного многочлена в форме Ньютона-2.png>)

# %% [markdown]
# # Разделенные разности (с кратными узлами)

# %% [markdown]
# стр 3.5
#
# По сути это
#
# ![Разделенные разности с кратными узлами-3.png](<attachment:Разделенные разности с кратными узлами-3.png>)
#
# Где
#
# ![Разделенные разности с кратными узлами-4.png](<attachment:Разделенные разности с кратными узлами-4.png>)
#
# ![Разделенные разности с кратными узлами-1.png](<attachment:Разделенные разности с кратными узлами-1.png>)

# %% [markdown]
# # Остаток и погрешность интерполирования

# %% [markdown]
# стр 2.3
#
# ![Остаток и погрешность интерполирования.png](<attachment:Остаток и погрешность интерполирования.png>)

# %% [markdown]
# # Задача интерполяции с кратными узлами

# %% [markdown]
# стр 3.0
#
# ![Задача интерполяции с кратными узлами-1.png](<attachment:Задача интерполяции с кратными узлами-1.png>)

# %% [markdown]
# # Записать вид интерполяционного многочлена  с кратными узлами в форме Ньютона

# %% [markdown]
# стр 3.5
#
# ![Записать вид интерполяционного многочлена  с кратными узлами в форме Ньютона-1.png](<attachment:Записать вид интерполяционного многочлена  с кратными узлами в форме Ньютона-1.png>)
#
# где
#
# ![Разделенные разности с кратными узлами-3.png](<attachment:Разделенные разности с кратными узлами-3.png>)
#
# ![Разделенные разности с кратными узлами-4.png](<attachment:Разделенные разности с кратными узлами-4.png>)
#
# ![Записать формулу интерполяционного многочлена в форме Ньютона-3.png](<attachment:Записать формулу интерполяционного многочлена в форме Ньютона-3.png>)

# %% [markdown]
# # Многочлен наилучшего равномерного приближения

# %% [markdown]
# стр 4.0
#
# ![Многочлен наилучшего равномерного приближения-1.png](<attachment:Многочлен наилучшего равномерного приближения-1.png>)

# %% [markdown]
# # Критерий многочлена наилучшего равномерного приближения + определение альтернанса

# %% [markdown]
# стр 4.0 и 4.1
#
# ![Критерий многочлена наилучшего равномерного приближения + определение альтернанса-1.png](<attachment:Критерий многочлена наилучшего равномерного приближения + определение альтернанса-1.png>)
#
# ![Критерий многочлена наилучшего равномерного приближения + определение альтернанса-2.png](<attachment:Критерий многочлена наилучшего равномерного приближения + определение альтернанса-2.png>)

# %% [markdown]
# # Многочлены Чебышева, их свойства

# %% [markdown]
# стр 4.2
#
# Что это
#
# ![Многочлены Чебышева, их свойства-1.png](<attachment:Многочлены Чебышева, их свойства-1.png>)
#
# и свойства... честно, не уверен. лучше перечитайте 4.4 и 4.5 самостоятельно
#
# ![Многочлены Чебышева, их свойства-2.png](<attachment:Многочлены Чебышева, их свойства-2.png>)
#
# ![Многочлены Чебышева, их свойства-3.png](<attachment:Многочлены Чебышева, их свойства-3.png>)
#
# ![Многочлены Чебышева, их свойства-4.png](<attachment:Многочлены Чебышева, их свойства-4.png>)
#
# ну или вот я уже сам вам параграф перекопировал
#
# ![Многочлены Чебышева, их свойства-5.png](<attachment:Многочлены Чебышева, их свойства-5.png>)
#
# ![Многочлены Чебышева, их свойства-6.png](<attachment:Многочлены Чебышева, их свойства-6.png>)

# %% [markdown]
# # Прямое и обратное преобразование Фурье

# %% [markdown]
# стр 5.0
#
# ![Прямое и обратное преобразование Фурье-1.png](<attachment:Прямое и обратное преобразование Фурье-1.png>)
#
# ![Прямое и обратное преобразование Фурье-2.png](<attachment:Прямое и обратное преобразование Фурье-2.png>)
#
# ![Прямое и обратное преобразование Фурье-3.png](<attachment:Прямое и обратное преобразование Фурье-3.png>)

# %% [markdown]
# # Сплайн порядка m

# %% [markdown]
# ![Сплайн порядка m-1.png](<attachment:Сплайн порядка m-1.png>)

# %% [markdown]
# # Постановка задачи наименьших квадратов (линейная регрессия)

# %% [markdown]
# по идее, стр 9.6
#
# ![Постановка задачи наименьших квадратов или линейная регрессия-1.png](<attachment:Постановка задачи наименьших квадратов или линейная регрессия-1.png>)

# %% [markdown]
# # Постановка задачи наилучшего приближения в гильбертовом пространстве

# %% [markdown]
# стр 9.2
#
# ![Постановка задачи наилучшего приближения в гильбертовом пространстве-1.png](<attachment:Постановка задачи наилучшего приближения в гильбертовом пространстве-1.png>)

# %% [markdown]
# # Система ортогональных многочленов

# %% [markdown]
# стр 10.3
#
# параграф 10.5
#
# я прям прямого определения не увидел, но вот что мне сформулировал Гемини
#
# ![Система ортогональных многочленов.jpg](<attachment:Система ортогональных многочленов.jpg>)

# %% [markdown]
# # Задача интерполяции функции двух переменных

# %% [markdown]
# стр 11.6
#
# честно, мне кажется тут мало
#
# ![Задача интерполяции функции двух переменных-1.png](<attachment:Задача интерполяции функции двух переменных-1.png>)

# %% [markdown]
# # Билинейный сплайн

# %% [markdown]
# стр 12.1
#
# ![Билинейный сплайн-1.png](<attachment:Билинейный сплайн-1.png>)

# %% [markdown]
# # Бикубический сплайн

# %% [markdown]
# стр 12.1
#
# ![Бикубический сплайн-1.png](<attachment:Бикубический сплайн-1.png>)

# %% [markdown]
# # Интерполяционная квадратурная формула

# %% [markdown]
# стр 13.3
#
# или это
#
# ![Интерполяционная квадратурная формула-1.png](<attachment:Интерполяционная квадратурная формула-1.png>)
#
# или это
#
# ![Интерполяционная квадратурная формула-2.png](<attachment:Интерполяционная квадратурная формула-2.png>)

# %% [markdown]
# # Квадратурная формула общего вида

# %% [markdown]
# стр 13.1
#
# ![Квадратурная формула общего вида-1.png](<attachment:Квадратурная формула общего вида-1.png>)

# %% [markdown]
# # Степень точности квадратурной формулы относительно произвольного базиса

# %% [markdown]
# стр 13.2
#
# ![Степень точности квадратурной формулы относительно произвольного базиса-1.png](<attachment:Степень точности квадратурной формулы относительно произвольного базиса-1.png>)

# %% [markdown]
# # Алгебраическая степень точности КФ

# %% [markdown]
# стр 13.2
#
# ![Алгебраическая степень точности КФ-1.png](<attachment:Алгебраическая степень точности КФ-1.png>)
#
# условия
#
# ![Степень точности квадратурной формулы относительно произвольного базиса-2.png](<attachment:Степень точности квадратурной формулы относительно произвольного базиса-2.png>)

# %% [markdown]
# # Симметричная КФ

# %% [markdown]
# стр 14.0
#
# ![Симметричная КФ-1.png](<attachment:Симметричная КФ-1.png>)

# %% [markdown]
# # КФ Ньютона--Котеса

# %% [markdown]
# стр 14.3
#
# ![КФ Ньютона--Котеса-1.png](<attachment:КФ Ньютона--Котеса-1.png>)
#
# еще некоторая информация
#
# ![КФ Ньютона--Котеса-2.png](<attachment:КФ Ньютона--Котеса-2.png>)
#
# ![КФ Ньютона--Котеса-3.png](<attachment:КФ Ньютона--Котеса-3.png>)

# %% [markdown]
# # Составная квадратурная формула

# %% [markdown]
# стр 15.4
#
# ![Составная квадратурная формула-1.png](<attachment:Составная квадратурная формула-1.png>)
#
# и какие-то начальные условия
#
# ![Составная квадратурная формула-2.png](<attachment:Составная квадратурная формула-2.png>)

# %% [markdown]
# # Квадратурная формула наивысшей АСТ

# %% [markdown]
# стр 16.0
#
# как сформулировал Гемини
#
# ![Квадратурная формула наивысшей АСТ-1.png](<attachment:Квадратурная формула наивысшей АСТ-1.png>)
#
# как описано в конспекте
#
# ![Квадратурная формула наивысшей АСТ-2.png](<attachment:Квадратурная формула наивысшей АСТ-2.png>)

# %% [markdown]
# # Кубатурные формулы общего вида

# %% [markdown]
# стр 17.0
#
# гемини
#
# ![Кубатурные формулы общего вида-2.png](<attachment:Кубатурные формулы общего вида-2.png>)
#
# из учебника
#
# ![Кубатурные формулы общего вида-1.png](<attachment:Кубатурные формулы общего вида-1.png>)
